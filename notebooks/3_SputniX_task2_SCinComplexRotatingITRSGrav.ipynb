# %% [markdown]
# # Задачка баллистика2
#
# Автор кода: Рожков Мирослав Андреевич

# %% [markdown]
# Загрузка и инициализация библиотек

# %%
import plotly.graph_objects as go # Для создание интерактивного графика
import numpy as np # работа с массивами
from scipy.integrate import solve_ivp # Численное интегрирование
from scipy import special # Вычисление присоединённых функций Лежандра
# блок библиотек astropy для перехода от GCRS к ITRS
from astropy.coordinates import CartesianRepresentation, SphericalRepresentation, GCRS, ITRS  # Описание координат и систем
from astropy.time import Time # Форматирование времени
import astropy.units as u # Система единиц иземерения

# %% [markdown]
# Создание классов для демонстрации ООП

# %%
class Vector():
    dim = "" # единицы измерения

    def __init__(self, name, x, y, z):
        self.name = name
        self.x = x
        self.y = y
        self.z = z
        self.numcord = np.array([x, y, z])

    def __str__(self):
        return f"    {self.x}\n{self.name} = {self.y}     {self.dim}\n    {self.z}"

    def rotate(self, A):
        self.numcord = np.matmul(A, self.numcord)
        self.x, self.y, self.z = self.numcord[0], self.numcord[1], self.numcord[2]

class Position(Vector):
    dim = "м"

    def __init__(self, name, x, y, z):
        super().__init__(name, x, y, z)
        self.norm = np.linalg.norm(self.numcord)

class Velocity(Vector):
    dim = "м/с"

class Acceleration(Vector):
    dim = "м/с2"

# %% [markdown]
# Используемые постоянные

# %%
fm = 3.986004415E14 # грав. параметр Земли, м3/с2
R0 = 6378136.3 # экваториальный радиус Земли, м
w0 = 7.292115e-5 # угловая скорость вращения Земли, 1/с

# %% [markdown]
# # Используемые функции и методы

# %%
# Вычисление присоединённых функций Лежандра
def Legendre(m, n, z):
    # Готовые операторы расчёта полиномов
    Pol, dPol = special.lpmn(m, n, z)
    # Особенности оператора
    for i in range(0, m+1):
        Pol[i, :] = (-1)**i * Pol[i, :]
        dPol[i, :] = (-1)**i * dPol[i, :]

    # нормировка согласно EGM96
    for j in range(0, n+1):
           Pol[0, j] = np.sqrt(2*j+1)*Pol[0, j]
           dPol[0, j] = np.sqrt(2*j+1)*dPol[0, j]
    for i in range(1, m+1):
        for j in range(i, n+1):
            factor = np.sqrt(2*(2*j+1)*special.factorial(j-i)/special.factorial(j+i))
            Pol[i, j] = factor*Pol[i, j]
            dPol[i, j] = factor*dPol[i, j]

    return Pol, dPol

def geoaccel(t, P, coeffs):
    # переход
    cart_coords = CartesianRepresentation(x=P.numcord, unit=u.m, copy=True)
    spher_coords = SphericalRepresentation.from_cartesian(cart_coords)
    GCRS_coords = GCRS(spher_coords, obstime=t0+t*u.s)
    ITRS_coords = GCRS_coords.transform_to(ITRS(obstime=t0+t*u.s))
    P = Position("P(ITRS)", ITRS_coords.x.value, ITRS_coords.y.value, ITRS_coords.z.value)
    # определение сферических координат
    r = P.norm
    az = np.arctan2(P.y, P.x) # долгота
    cosmaz, sinmaz = np.zeros(m_max+1), np.zeros(m_max+1)
    for i in range(0, m_max+1):
        cosmaz[i] = np.cos(i*az)
        sinmaz[i] = np.sin(i*az)
    # синус и косинус широты
    sinel = P.z/r
    cosel = np.sqrt(1-sinel**2)

    g = Acceleration("g", -fm/r**2, 0, 0) # ускорение от сферичного шара

    Equator_Singularity = False # проверка на точки сингулярности
    if cosel == 1: # в полюсах - ускорение шара
        pass
    else:
        if sinel == 0: # в экваторе
            Equator_Singularity = True

        # Расчёт по EGM96 в сферических координатах g(r, el, az)
        Pmn, dPmn = Legendre(m_max, n_max, sinel)
        for i in range(0, coeffs_row):
            n = int(coeffs[i, 0])
            m = int(coeffs[i, 1])
            C = coeffs[i, 2]
            S = coeffs[i, 3]
            fmR0nRmn2 = fm * R0**n / r**(n+2)

            g.x = g.x - fmR0nRmn2 * (n+1) * Pmn[m, n]*(C*cosmaz[m]+S*sinmaz[m])
            g.y = g.y + fmR0nRmn2 * dPmn[m, n]*(C*cosmaz[m]+S*sinmaz[m])
            if not Equator_Singularity:
                g.z = g.z + fmR0nRmn2 * m * Pmn[m, n]*(S*cosmaz[m]-C*sinmaz[m]) / sinel

        g.numcord = np.array([g.x, g.y, g.z])

    # Переход из сферических в прямоугольные координаты
    cosaz = cosmaz[1]
    sinaz = sinmaz[1]
    rot = np.array([[cosel*cosaz, sinel*cosaz, -sinaz],
                    [cosel*sinaz, sinel*sinaz,  cosaz],
                    [sinel,       -cosel,           0]])
    g.rotate(rot)

    # Возвращение в инерциальную ГСК
    ITRS_gcord = ITRS(x=g.numcord, obstime=t0+t*u.s)
    GCRS_gcord = ITRS_gcord.transform_to(GCRS(obstime=t0+t*u.s))
    cart_gcord = CartesianRepresentation.from_representation(GCRS_gcord)
    g = Acceleration("g", cart_gcord.x.value, cart_gcord.y.value, cart_gcord.z.value)

    return g

# Правые части ОДУ
def SimpleMotionEquation(t, y):

    P = Position("P", y[0], y[1], y[2])
    V = Velocity("V", y[3], y[4], y[5])
    fmRm3 = -fm/P.norm**3

    return [V.x, V.y, V.z, P.x*fmRm3, P.y*fmRm3, P.z*fmRm3]

def ComplexGravity(t, y):

    Pt = Position("P", y[0], y[1], y[2])
    Vt = Velocity("V", y[3], y[4], y[5])
    g = geoaccel(t, Pt, coeffs)

    return [Vt.x, Vt.y, Vt.z, g.x, g.y, g.z]

# %% [markdown]
# # Численное интегрирование
# Начальные данные

# %%
t0 = Time('2022-11-28 11:00:00', format='iso', scale='utc')
P0 = Position("P0", 1702631.521, 126415.744, 6769207.534)
V0 = Velocity("V0", -5734.531, -4667.074, 1528.123)
print(f"Фазовые параметры КА на момент времени {t0}")
print(P0)
print("-------------------------------")
print(V0)
# Out:
# Фазовые параметры КА на момент времени 2022-11-28 11:00:00.000
#     1702631.521
# P0 = 126415.744     м
#     6769207.534
# -------------------------------
#     -5734.531
# V0 = -4667.074     м/с
#     1528.123

# %% [markdown]
# Переход от GCRS к ITRS

# %%
cart_coords = CartesianRepresentation(x=P0.numcord, unit=u.m, copy=True)
spher_coords = SphericalRepresentation.from_cartesian(cart_coords)
GCRS_coords = GCRS(spher_coords, obstime=t0)
ITRS_coords = GCRS_coords.transform_to(ITRS(obstime=t0))
P0_ITRS = Position("P0(ITRS)", ITRS_coords.x.value, ITRS_coords.y.value, ITRS_coords.z.value)
print(f"Положение КА на момент времени {t0} в связанной с Землёй системе координат ITRS")
print(P0_ITRS)
print("--------------------")
if P0.norm == P0_ITRS.norm:
    print(f"Перевод прошёл кооректно, геоцентрическое расстояние КА не изменилось:")
else:
    print(f"(!)Высота орбиты изменилась(!)")
print(f"Высота орбиты в GCRS = {P0.norm-R0}, м.")
print(f"Высота орбиты в ITRS = {P0_ITRS.norm-R0}, м.")
# Out:
# Положение КА на момент времени 2022-11-28 11:00:00.000 в связанной с Землёй системе координат ITRS
#     -1137720.0232414473
# P0(ITRS) = 1252955.074868381     м
#     6772946.360637537
# --------------------
# Перевод прошёл кооректно, геоцентрическое расстояние КА не изменилось:
# Высота орбиты в GCRS = 603060.2790254187, м.
# Высота орбиты в ITRS = 603060.2790254187, м.

# %% [markdown]
# Выгрузка данных из EGM96

# %%
# Загрузка коэффициентов C и S из таблицы модели EGM96
coeffs_all = np.loadtxt(fname="egm96_to360.txt")
m_max, n_max = 10, 10
coeffs = coeffs_all[:63,:] # только коэффициенты до 10х10 гармоники
coeffs_row = np.size(coeffs[:,0])

# %% [markdown]
# Численное решение уравнения движения

# %%
step = 60 # шаг записи данных, с
start = 0 # начало записи данных, с
t_end = 24*3600 # конец интервала интегрирования, с
end = t_end + step
t_eval = np.arange(start, end, step)
sol = solve_ivp(ComplexGravity, [0, t_end], np.append(P0.numcord, V0.numcord),\
                t_eval=t_eval, rtol=1e-3, atol=0.1, max_step=30)
print(sol.success)
# Out:
# True

# %% [markdown]
# # Вывод результатов
# Конечные значение (через сутки).

# %%
tk = t0 + sol.t[-1]*u.s
Pk = Position("Pk", sol.y[0,-1], sol.y[1,-1], sol.y[2,-1])
Vk = Velocity("Vk", sol.y[3,-1], sol.y[4,-1], sol.y[5,-1])
print(f"Фазовые параметры КА на момент времени {tk}, с")
print(Pk)
print("-------------------------")
print(Vk)
print(Pk.norm)
# Out:
# Фазовые параметры КА на момент времени 2022-11-29 11:00:00.000, с
#     3320468.478493867
# Pk = 1263445.4138161065     м
#     6022067.141687628
# -------------------------
#     -5119.0776936585335
# Vk = -4131.315218603151     м/с
#     3671.935540627964
# 6991930.912799276

# %% [markdown]
# Визуализация орбитального движения КА.

# %%
fig = go.Figure(data=[go.Scatter3d(x=sol.y[0,:], y=sol.y[1,:], z=sol.y[2,:], mode='lines', line=dict(width=8))])
fig.update_layout(height=600, width=600)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="e0ba341b-795a-4710-a8a3-34fd4810dc8c" class="plotly-graph-div" style="height:600px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e0ba341b-795a-4710-a8a3-34fd4810dc8c")) {                    Plotly.newPlot(                        "e0ba341b-795a-4710-a8a3-34fd4810dc8c",                        [{"line":{"width":8},"mode":"lines","x":[1702631.521,1355183.409052353,1001962.0817735884,644459.2248972534,284196.86980364885,-77281.33615481015,-438429.8176751405,-797713.5939508263,-1153612.4820515786,-1504624.5716000395,-1849270.7408461964,-2186099.828756021,-2513694.070239006,-2830674.579448496,-3135706.768165211,-3427505.6357482625,-3704840.890965184,-3966541.8778465264,-4211502.283956143,-4438684.613117109,-4647124.406992746,-4835934.201440883,-5004307.204282538,-5151520.680897606,-5276939.032300479,-5380016.544391352,-5460299.76144082,-5517429.220399315,-5551144.902975455,-5561287.165106377,-5547785.49818752,-5510672.622563665,-5450081.21275171,-5366243.547330439,-5259490.925722565,-5130252.709640825,-4979054.959367496,-4806518.653508183,-4613357.48683128,-4400375.243948732,-4168462.7488948684,-3918594.39274945,